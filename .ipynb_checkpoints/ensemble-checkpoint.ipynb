# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C281-9A4A
#
#  Directory of C:\Users\Stanley\Downloads\ensemble
#
# 04/17/2020  05:43 PM    <DIR>          .
# 04/17/2020  05:43 PM    <DIR>          ..
# 04/17/2020  05:43 PM    <DIR>          .ipynb_checkpoints
# 04/17/2020  05:42 PM            22,960 ensemble.ipynb
# 04/17/2020  05:40 PM            23,612 resnext50_32x4d_tfms_5_sub_10_10_9_299.csv
# 04/17/2020  04:59 PM            23,571 resnext50_32x4d_tfms_5_sub_5_5_4_256.csv
#                3 File(s)         70,143 bytes
#                3 Dir(s)  62,598,770,688 bytes free

# %%
import pandas as pd
from scipy import stats
import numpy as np

# %%
sub1 = pd.read_csv('resnext50_32x4d_tfms_5_sub_10_10_9_299.csv')
sub2 = pd.read_csv('resnext50_32x4d_tfms_5_sub_5_5_4_256.csv')
# sub3 = pd.read_csv('se_resnext101_32x4d.csv')
# sub4 = pd.read_csv('se_resnext50_32x4d_new.csv')
# sub5 = pd.read_csv('se_resnext101_32x4d_new.csv')

# %%
sub1.head()
# Out:
#                       +ACI-image+ACI-  +ACI-target+ACI-
# 0  aadawlxbmapqrblgxyzarhjasgiobu.png          0.411921
# 1  abpxvdfyhaaohzcrngcucmhffwizxs.jpg          0.071222
# 2  aclkjfvackiieiznzfcwienplielrj.jpg          0.993954
# 3  aelkivmayxgsdjosiibfgmkvfrjvjk.jpg          0.526727
# 4  aelzzshpfxerelefnkatpczktuxjln.jpg          0.000078

# %%
ids = sub1["+ACI-image+ACI-"]
columns = sub1.columns

# %%
sub1 = sub1.iloc[:, 1:]
sub2 = sub2.iloc[:, 1:]
# sub3 = sub3.iloc[:, 1:]
# sub4 = sub4.iloc[:, 1:]
# sub5 = sub5.iloc[:, 1:]

# %%
trim_mean = stats.trim_mean([sub1.values, sub2.values, sub3.values, sub4.values, sub5.values], 0.2)
trim_mean
# Out:
# array([[6.41708775e-06, 1.69311407e-08, 3.31379393e-08, ...,
#         5.53440366e-06, 1.18735403e-09, 5.21563510e-11],
#        [1.79744847e-04, 2.37360123e-02, 5.71016897e-06, ...,
#         2.88616105e-05, 8.88124833e-06, 9.19537185e-05],
#        [1.98057635e-07, 4.79001653e-07, 1.55138179e-06, ...,
#         4.31779239e-05, 3.02056725e-09, 1.46179027e-08],
#        ...,
#        [1.21994290e-05, 2.59031471e-07, 3.66929405e-06, ...,
#         4.59729359e-06, 5.50424634e-09, 5.89685308e-10],
#        [1.10162842e-03, 6.39002043e-01, 4.17096763e-06, ...,
#         1.02998673e-03, 4.01827023e-06, 2.01010531e-05],
#        [1.63358413e-05, 9.18371503e-04, 3.28395666e-05, ...,
#         1.02111885e-05, 1.06124953e-06, 4.61169928e-05]])

# %%
sub = pd.DataFrame({'FILE': ids})
for i, c in enumerate(df_sample.columns[1:]):
    sub[c] = trim_mean[:,i]
sub.head()
# Out:
#            FILE  Pteraster_capensis      Porifera  \
# 0  4SPI630.jpeg        6.417088e-06  1.693114e-08
# 1  3QF54TU.jpeg        1.797448e-04  2.373601e-02
# 2  M0C2F4B.jpeg        1.980576e-07  4.790017e-07
# 3  P19POBA.jpeg        4.587025e-06  1.058503e-04
# 4  70HSC4W.jpeg        1.259450e-06  2.845975e-06
#
#    Astropecten_irregularis_pontoporeus  Terebratulina_sp_  \
# 0                         3.313794e-08       6.388484e-09
# 1                         5.710169e-06       1.009732e-02
# 2                         1.551382e-06       6.977394e-09
# 3                         1.129338e-06       1.858229e-08
# 4                         3.719549e-06       8.991305e-09
#
#    Neolithodes_asperrimus  Munida_benguela  Cypraeovula_iutsui  \
# 0            1.299074e-08     3.990627e-09        4.265238e-10
# 1            3.811768e-06     6.238468e-07        4.172031e-06
# 2            4.467689e-06     7.213819e-08        1.917484e-09
# ...

# %%
sub.to_csv("avg.csv", index=False)
